# %%
import _pickle as cPickle
import docplex
from docplex.mp.model import Model

# %%
with open(r"../Data/test_optimize.pickle", "rb") as input_file:
    df = cPickle.load(input_file)

with open(r"../Data/team.pickle", "rb") as input_file:
    team = cPickle.load(input_file)

# %%
team_dict = dict(zip(team.code.to_list(),team.short_name.to_list()))

# %%
df
# Out:
#       id     web_name  team  element_type  now_cost  predict_points  \
# 0      1       Cédric     1             2        42        1.658569
# 1      3        Xhaka     1             3        51       59.257935
# 2      4       Elneny     1             3        42        6.226771
# 3      5      Holding     1             2        42        1.271105
# 4      6       Partey     1             3        48       40.345520
# ..   ...          ...   ...           ...       ...             ...
# 662  625  Diego Costa    20             4        55       10.143930
# 663  629       Traoré    20             3        45       10.171195
# 664  657       Fraser    20             4        45        0.082976
# 665  658    Griffiths    20             3        45        0.082976
# 666  664    Lembikisa    20             2        40        2.056752
#
#      actual_points
# 0                2
# 1               62
# 2                4
# 3                4
# 4               42
# ..             ...
# 662              7
# 663             12
# 664              0
# 665              0
# 666              1
#
# [667 rows x 7 columns]

# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in /home/caleb/PythonEnvs/FPL/lib/python3.10/site-packages (2.7.0)

# %%
import scipy
import numpy as np
from scipy.optimize import minimize
import pulp

# %%
def select_team(expected_scores, prices, positions, clubs, total_budget=100, sub_factor=0.2):
    num_players = len(expected_scores)
    model = pulp.LpProblem("Constrained value maximisation", pulp.LpMaximize)
    decisions = [
        pulp.LpVariable("x{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ]
    captain_decisions = [
        pulp.LpVariable("y{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ]
    sub_decisions = [
        pulp.LpVariable("z{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ] 


    # objective function:
    model += sum((captain_decisions[i] + decisions[i] + sub_decisions[i]*sub_factor) * expected_scores[i]
                 for i in range(num_players)), "Objective"

    # cost constraint
    model += sum((decisions[i] + sub_decisions[i]) * prices[i] for i in range(num_players)) <= total_budget  # total cost

    # position constraints
    # 1 starting goalkeeper
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 1) == 1
    # 2 total goalkeepers
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 1) == 2

    # 3-5 starting defenders
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 2) >= 3
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 2) <= 5
    # 5 total defenders
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 2) == 5

    # 3-5 starting midfielders
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 3) >= 3
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 3) <= 5
    # 5 total midfielders
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 3) == 5

    # 1-3 starting attackers
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 4) >= 1
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 4) <= 3
    # 3 total attackers
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 4) == 3

    # club constraint
    for club_id in np.unique(clubs):
        model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if clubs[i] == club_id) <= 3  # max 3 players

    model += sum(decisions) == 11  # total team size
    model += sum(captain_decisions) == 1  # 1 captain
    
    for i in range(num_players):  
        model += (decisions[i] - captain_decisions[i]) >= 0  # captain must also be on team
        model += (decisions[i] + sub_decisions[i]) <= 1  # subs must not be on team

    model.solve()
    print("Total expected score = {}".format(model.objective.value()))

    return decisions, captain_decisions, sub_decisions

# %%
df.columns
# Out:
# Index(['id', 'web_name', 'team', 'element_type', 'now_cost', 'predict_points',
#        'actual_points'],
#       dtype='object')

# %%
expected_scores = df.predict_points
prices = df.now_cost / 10
position = df.element_type
team = df.team
names = df.web_name

decisions, captain_decisions, sub_decisions = select_team(expected_scores.values, prices.values, position.values, team.values)
# Out:
# /home/caleb/PythonEnvs/FPL/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/caleb/PythonEnvs/FPL/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dcf3f45388fe493b8465d26ad47978d9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dcf3f45388fe493b8465d26ad47978d9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1373 COLUMNS
# At line 16645 RHS
# At line 18014 BOUNDS
# At line 20016 ENDATA
# Problem MODEL has 1368 rows, 2001 columns and 9268 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1079.94 - 0.00 seconds
# Cgl0004I processed model has 1365 rows, 2001 columns (2001 integer (2001 of which binary)) and 8671 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.603175
# Cbc0038I Solution found of -1075.99
# Cbc0038I Before mini branch and bound, 1999 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -1076.38
# Cbc0038I Reduced cost fixing fixed 1906 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.06032 (2) obj. -1076.38 iterations 8
# Cbc0038I Pass   2: suminf.    0.60317 (2) obj. -1079.94 iterations 14
# Cbc0038I Pass   3: suminf.    0.33724 (4) obj. -1076.38 iterations 14
# Cbc0038I Pass   4: suminf.    0.33724 (4) obj. -1076.38 iterations 10
# Cbc0038I Pass   5: suminf.    0.41270 (2) obj. -1079.07 iterations 15
# Cbc0038I Pass   6: suminf.    0.00258 (2) obj. -1076.38 iterations 12
# Cbc0038I Pass   7: suminf.    0.91592 (4) obj. -1076.38 iterations 21
# Cbc0038I Pass   8: suminf.    0.75835 (4) obj. -1076.38 iterations 5
# Cbc0038I Pass   9: suminf.    0.47619 (2) obj. -1078.08 iterations 10
# Cbc0038I Pass  10: suminf.    0.21820 (2) obj. -1076.38 iterations 12
# Cbc0038I Pass  11: suminf.    0.13609 (2) obj. -1076.38 iterations 11
# Cbc0038I Pass  12: suminf.    0.13609 (2) obj. -1076.38 iterations 10
# Cbc0038I Pass  13: suminf.    0.28571 (2) obj. -1077.36 iterations 14
# Cbc0038I Pass  14: suminf.    0.66934 (2) obj. -1076.38 iterations 9
# Cbc0038I Pass  15: suminf.    0.26761 (4) obj. -1076.38 iterations 10
# Cbc0038I Pass  16: suminf.    0.92100 (4) obj. -1076.38 iterations 16
# Cbc0038I Pass  17: suminf.    0.92100 (4) obj. -1076.38 iterations 4
# Cbc0038I Pass  18: suminf.    0.38869 (2) obj. -1076.38 iterations 8
# Cbc0038I Pass  19: suminf.    0.60317 (2) obj. -1077.79 iterations 13
# Cbc0038I Pass  20: suminf.    0.43914 (3) obj. -1076.38 iterations 15
# Cbc0038I Pass  21: suminf.    0.41366 (2) obj. -1076.38 iterations 11
# Cbc0038I Pass  22: suminf.    0.57143 (2) obj. -1078.94 iterations 12
# Cbc0038I Pass  23: suminf.    0.18205 (2) obj. -1076.38 iterations 14
# Cbc0038I Pass  24: suminf.    0.21177 (2) obj. -1076.38 iterations 19
# Cbc0038I Solution found of -1076.52
# Cbc0038I Before mini branch and bound, 1982 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 10 rows 19 columns
# Cbc0038I Mini branch and bound improved solution from -1076.52 to -1078.26 (0.08 seconds)
# Cbc0038I Round again with cutoff of -1078.6
# Cbc0038I Reduced cost fixing fixed 1964 variables on major pass 3
# Cbc0038I Pass  25: suminf.    0.39783 (2) obj. -1078.6 iterations 0
# Cbc0038I Pass  26: suminf.    0.60317 (2) obj. -1079.94 iterations 13
# Cbc0038I Pass  27: suminf.    0.25085 (4) obj. -1078.6 iterations 3
# Cbc0038I Solution found of -1078.74
# Cbc0038I Before mini branch and bound, 1995 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 2 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I Round again with cutoff of -1079.1
# Cbc0038I Reduced cost fixing fixed 1972 variables on major pass 4
# Cbc0038I Pass  28: suminf.    0.47471 (2) obj. -1079.1 iterations 7
# Cbc0038I Pass  29: suminf.    0.60317 (2) obj. -1079.94 iterations 10
# Cbc0038I Pass  30: suminf.    0.61290 (2) obj. -1079.71 iterations 2
# Cbc0038I Pass  31: suminf.    0.61290 (2) obj. -1079.71 iterations 4
# Cbc0038I Pass  32: suminf.    0.45625 (2) obj. -1079.1 iterations 7
# Cbc0038I Pass  33: suminf.    0.42232 (2) obj. -1079.1 iterations 8
# Cbc0038I Pass  34: suminf.    0.47619 (2) obj. -1079.45 iterations 10
# Cbc0038I Pass  35: suminf.    0.87674 (4) obj. -1079.1 iterations 4
# Cbc0038I Pass  36: suminf.    0.87674 (4) obj. -1079.1 iterations 4
# Cbc0038I Pass  37: suminf.    0.87674 (4) obj. -1079.1 iterations 1
# Cbc0038I Pass  38: suminf.    0.87674 (4) obj. -1079.1 iterations 1
# Cbc0038I Pass  39: suminf.    0.60317 (2) obj. -1079.94 iterations 6
# Cbc0038I Pass  40: suminf.    0.47471 (2) obj. -1079.1 iterations 8
# Cbc0038I Pass  41: suminf.    0.47471 (2) obj. -1079.1 iterations 0
# Cbc0038I Pass  42: suminf.    0.47471 (2) obj. -1079.1 iterations 0
# Cbc0038I Pass  43: suminf.    0.54839 (2) obj. -1079.6 iterations 10
# Cbc0038I Pass  44: suminf.    0.43099 (2) obj. -1079.1 iterations 7
# Cbc0038I Pass  45: suminf.    0.53968 (2) obj. -1079.81 iterations 11
# Cbc0038I Pass  46: suminf.    0.41270 (2) obj. -1079.33 iterations 4
# Cbc0038I Pass  47: suminf.    0.37860 (2) obj. -1079.1 iterations 7
# Cbc0038I Pass  48: suminf.    0.41270 (2) obj. -1079.33 iterations 8
# Cbc0038I Pass  49: suminf.    1.19449 (4) obj. -1079.1 iterations 5
# Cbc0038I Pass  50: suminf.    0.97248 (4) obj. -1079.1 iterations 5
# Cbc0038I Pass  51: suminf.    0.22222 (2) obj. -1079.39 iterations 9
# Cbc0038I Pass  52: suminf.    0.17839 (2) obj. -1079.1 iterations 9
# Cbc0038I Pass  53: suminf.    0.22581 (2) obj. -1079.3 iterations 8
# Cbc0038I Pass  54: suminf.    0.17839 (2) obj. -1079.1 iterations 11
# Cbc0038I Pass  55: suminf.    1.21386 (4) obj. -1079.1 iterations 8
# Cbc0038I Pass  56: suminf.    1.21386 (4) obj. -1079.1 iterations 4
# Cbc0038I Pass  57: suminf.    0.60317 (2) obj. -1079.94 iterations 9
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1989 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 4 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.13 seconds)
# Cbc0038I After 0.13 seconds - Feasibility pump exiting with objective of -1078.74 - took 0.09 seconds
# Cbc0012I Integer solution of -1078.7404 found by feasibility pump after 0 iterations and 0 nodes (0.13 seconds)
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 0 rows 0 columns
# Cbc0013I At root node, 0 cuts changed objective from -1079.9443 to -1079.9443 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -1078.7404 best solution, best possible -1079.4206 (0.13 seconds)
# Cbc0001I Search completed - best objective -1078.74038009649, took 18 iterations and 2 nodes (0.14 seconds)
# Cbc0032I Strong branching done 8 times (26 iterations), fathomed 1 nodes and fixed 1 variables
# Cbc0035I Maximum depth 0, 1991 variables fixed on reduced cost
# Cuts at root node changed objective from -1079.94 to -1079.42
# Probing was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1078.74038010
# Enumerated nodes:               2
# Total iterations:               18
# Time (CPU seconds):             0.13
# Time (Wallclock seconds):       0.14
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.15
#
# Total expected score = 1078.7403800964355

# %%
pos_map = {1:'GK', 2:'DEF', 3: 'MID', 4:'FWD'}
for i in range(df.shape[0]):
    if decisions[i].value() != 0:
        print(f'{names[i]} {pos_map[position[i]]}: {expected_scores[i]} points at ${prices[i]}')
print('subs')
for i in range(df.shape[0]):
    if sub_decisions[i].value() != 0:
        print(f'{names[i]} {pos_map[position[i]]}: {expected_scores[i]} points at ${prices[i]}')
#print('Capt')
#for i in range(df.shape[0]):
#    if captain_decisions[i].value != 0:
#        print(f'Captain: {names[i]} score: {captain_decisions[i].value}')
# Out:
# Ødegaard MID: 77.52822875976562 points at $6.4
# Raya GK: 56.88882827758789 points at $4.6
# Trossard MID: 82.91353607177734 points at $7.1
# Maddison MID: 79.3056869506836 points at $8.2
# Firmino FWD: 89.04657745361328 points at $8.1
# Cancelo DEF: 65.36078643798828 points at $7.4
# Haaland FWD: 119.04466247558594 points at $12.2
# Trippier DEF: 90.45354461669922 points at $5.9
# Schär DEF: 60.936946868896484 points at $4.9
# Almirón MID: 91.85137176513672 points at $5.8
# Kane FWD: 101.47588348388672 points at $11.6
# subs
# White DEF: 58.11398696899414 points at $4.7
# Tarkowski DEF: 52.87712097167969 points at $4.4
# Andreas MID: 59.64226531982422 points at $4.6
# Ward GK: 53.81494903564453 points at $4.1
