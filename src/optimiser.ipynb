# %%
import _pickle as cPickle
import docplex
from docplex.mp.model import Model

# %%
with open(r"../Data/test_optimize.pickle", "rb") as input_file:
    df = cPickle.load(input_file)

with open(r"../Data/team.pickle", "rb") as input_file:
    team = cPickle.load(input_file)

# %%
team_dict = dict(zip(team.code.to_list(),team.short_name.to_list()))

# %%
df
# Out:
#       id     web_name  team  element_type  now_cost  predict_points  \
# 0      1       Cédric     1             2        42        1.452501
# 1      3        Xhaka     1             3        51       56.542370
# 2      4       Elneny     1             3        42        2.317113
# 3      5      Holding     1             2        42        1.452501
# 4      6       Partey     1             3        48       38.903732
# ..   ...          ...   ...           ...       ...             ...
# 662  625  Diego Costa    20             4        55        9.489326
# 663  629       Traoré    20             3        45       10.521433
# 664  657       Fraser    20             4        45        0.350952
# 665  658    Griffiths    20             3        45        0.350952
# 666  664    Lembikisa    20             2        40        4.080155
#
#      actual_points
# 0                2
# 1               62
# 2                4
# 3                4
# 4               42
# ..             ...
# 662              7
# 663             12
# 664              0
# 665              0
# 666              1
#
# [667 rows x 7 columns]

# %%
import scipy
import numpy as np
from scipy.optimize import minimize
import pulp

# %%
def select_team(expected_scores, prices, positions, clubs, total_budget=100, sub_factor=0.2):
    num_players = len(expected_scores)
    model = pulp.LpProblem("Constrained value maximisation", pulp.LpMaximize)
    decisions = [
        pulp.LpVariable("x{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ]
    captain_decisions = [
        pulp.LpVariable("y{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ]
    sub_decisions = [
        pulp.LpVariable("z{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ] 


    # objective function:
    model += sum((captain_decisions[i] + decisions[i] + sub_decisions[i]*sub_factor) * expected_scores[i]
                 for i in range(num_players)), "Objective"

    # cost constraint
    model += sum((decisions[i] + sub_decisions[i]) * prices[i] for i in range(num_players)) <= total_budget  # total cost

    # position constraints
    # 1 starting goalkeeper
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 1) == 1
    # 2 total goalkeepers
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 1) == 2

    # 3-5 starting defenders
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 2) >= 3
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 2) <= 5
    # 5 total defenders
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 2) == 5

    # 3-5 starting midfielders
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 3) >= 3
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 3) <= 5
    # 5 total midfielders
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 3) == 5

    # 1-3 starting attackers
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 4) >= 1
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 4) <= 3
    # 3 total attackers
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 4) == 3

    # club constraint
    for club_id in np.unique(clubs):
        model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if clubs[i] == club_id) <= 3  # max 3 players

    model += sum(decisions) == 11  # total team size
    model += sum(captain_decisions) == 1  # 1 captain
    
    for i in range(num_players):  
        model += (decisions[i] - captain_decisions[i]) >= 0  # captain must also be on team
        model += (decisions[i] + sub_decisions[i]) <= 1  # subs must not be on team

    model.solve()
    print("Total expected score = {}".format(model.objective.value()))

    return decisions, captain_decisions, sub_decisions

# %%
df.columns
# Out:
# Index(['id', 'web_name', 'team', 'element_type', 'now_cost', 'predict_points',
#        'actual_points'],
#       dtype='object')

# %%
expected_scores = df.predict_points
prices = df.now_cost / 10
position = df.element_type
team = df.team
names = df.web_name

decisions, captain_decisions, sub_decisions = select_team(expected_scores.values, prices.values, position.values, team.values)
# Out:
# /home/caleb/PythonEnvs/FPL/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/caleb/PythonEnvs/FPL/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/83ac30aba6cc46b68b9b5be6cb25eb2e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/83ac30aba6cc46b68b9b5be6cb25eb2e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1373 COLUMNS
# At line 16645 RHS
# At line 18014 BOUNDS
# At line 20016 ENDATA
# Problem MODEL has 1368 rows, 2001 columns and 9268 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1075.42 - 0.00 seconds
# Cgl0004I processed model has 1365 rows, 2001 columns (2001 integer (2001 of which binary)) and 8671 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.451613
# Cbc0038I Pass   1: suminf.    0.33735 (2) obj. -1063.69 iterations 17
# Cbc0038I Solution found of -988.023
# Cbc0038I Before mini branch and bound, 1998 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from -988.023 to -1062.99 (0.04 seconds)
# Cbc0038I Round again with cutoff of -1064.23
# Cbc0038I Reduced cost fixing fixed 1476 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.39437 (2) obj. -1073.29 iterations 2
# Cbc0038I Pass   3: suminf.    0.98458 (2) obj. -1064.23 iterations 17
# Cbc0038I Pass   4: suminf.    1.47730 (4) obj. -1064.23 iterations 10
# Cbc0038I Pass   5: suminf.    1.00000 (3) obj. -1064.23 iterations 13
# Cbc0038I Pass   6: suminf.    0.56799 (3) obj. -1064.23 iterations 9
# Cbc0038I Pass   7: suminf.    0.37987 (4) obj. -1064.23 iterations 18
# Cbc0038I Pass   8: suminf.    0.39437 (2) obj. -1073.29 iterations 19
# Cbc0038I Pass   9: suminf.    0.98458 (2) obj. -1064.23 iterations 13
# Cbc0038I Pass  10: suminf.    0.80711 (2) obj. -1064.23 iterations 17
# Cbc0038I Pass  11: suminf.    0.80711 (2) obj. -1064.23 iterations 15
# Cbc0038I Pass  12: suminf.    0.87500 (2) obj. -1067.89 iterations 18
# Cbc0038I Pass  13: suminf.    0.89237 (2) obj. -1064.23 iterations 20
# Cbc0038I Pass  14: suminf.    1.34774 (4) obj. -1064.23 iterations 20
# Cbc0038I Pass  15: suminf.    0.48122 (3) obj. -1064.23 iterations 13
# Cbc0038I Pass  16: suminf.    0.62516 (2) obj. -1064.23 iterations 21
# Cbc0038I Pass  17: suminf.    0.62516 (2) obj. -1064.23 iterations 0
# Cbc0038I Pass  18: suminf.    0.35000 (2) obj. -1068.95 iterations 16
# Cbc0038I Pass  19: suminf.    0.65030 (2) obj. -1064.23 iterations 19
# Cbc0038I Pass  20: suminf.    0.04509 (4) obj. -1064.23 iterations 14
# Cbc0038I Pass  21: suminf.    0.02562 (2) obj. -1064.23 iterations 9
# Cbc0038I Pass  22: suminf.    1.00000 (3) obj. -1064.23 iterations 22
# Cbc0038I Pass  23: suminf.    1.00000 (3) obj. -1064.23 iterations 9
# Cbc0038I Pass  24: suminf.    0.88804 (3) obj. -1064.23 iterations 6
# Cbc0038I Pass  25: suminf.    1.63062 (5) obj. -1064.23 iterations 19
# Cbc0038I Pass  26: suminf.    1.14322 (5) obj. -1064.23 iterations 13
# Cbc0038I Pass  27: suminf.    1.14322 (5) obj. -1064.23 iterations 0
# Cbc0038I Pass  28: suminf.    0.65517 (2) obj. -1071.6 iterations 20
# Cbc0038I Pass  29: suminf.    0.53521 (2) obj. -1068.11 iterations 5
# Cbc0038I Pass  30: suminf.    0.80124 (2) obj. -1064.23 iterations 14
# Cbc0038I Pass  31: suminf.    0.67844 (4) obj. -1064.23 iterations 23
# Cbc0038I Rounding solution of -1066.3 is better than previous of -1062.99
#
# Cbc0038I Before mini branch and bound, 1971 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 11 rows 22 columns
# Cbc0038I Mini branch and bound improved solution from -1066.3 to -1067.26 (0.09 seconds)
# Cbc0038I Round again with cutoff of -1068.89
# Cbc0038I Reduced cost fixing fixed 1815 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.40000 (2) obj. -1074.26 iterations 3
# Cbc0038I Pass  32: suminf.    0.84851 (2) obj. -1068.89 iterations 10
# Cbc0038I Pass  33: suminf.    1.64557 (4) obj. -1068.89 iterations 16
# Cbc0038I Pass  34: suminf.    0.62857 (2) obj. -1069.49 iterations 12
# Cbc0038I Pass  35: suminf.    0.67864 (2) obj. -1068.89 iterations 14
# Cbc0038I Pass  36: suminf.    0.81755 (5) obj. -1068.89 iterations 19
# Cbc0038I Pass  37: suminf.    0.71226 (3) obj. -1068.89 iterations 10
# Cbc0038I Pass  38: suminf.    0.82515 (2) obj. -1068.89 iterations 9
# Cbc0038I Pass  39: suminf.    1.00000 (3) obj. -1068.89 iterations 14
# Cbc0038I Pass  40: suminf.    1.00000 (3) obj. -1068.89 iterations 6
# Cbc0038I Pass  41: suminf.    0.77561 (3) obj. -1068.89 iterations 5
# Cbc0038I Pass  42: suminf.    0.40000 (2) obj. -1070.22 iterations 6
# Cbc0038I Pass  43: suminf.    0.51082 (2) obj. -1068.89 iterations 13
# Cbc0038I Pass  44: suminf.    1.51342 (5) obj. -1068.89 iterations 11
# Cbc0038I Pass  45: suminf.    0.55172 (2) obj. -1070.53 iterations 10
# Cbc0038I Pass  46: suminf.    0.46719 (3) obj. -1068.89 iterations 6
# Cbc0038I Pass  47: suminf.    0.98588 (2) obj. -1068.89 iterations 13
# Cbc0038I Pass  48: suminf.    0.98588 (2) obj. -1068.89 iterations 0
# Cbc0038I Pass  49: suminf.    0.57143 (2) obj. -1070.19 iterations 14
# Cbc0038I Pass  50: suminf.    0.68021 (2) obj. -1068.89 iterations 13
# Cbc0038I Pass  51: suminf.    1.01159 (4) obj. -1068.89 iterations 10
# Cbc0038I Pass  52: suminf.    0.61899 (3) obj. -1068.89 iterations 10
# Cbc0038I Pass  53: suminf.    0.71856 (2) obj. -1068.89 iterations 11
# Cbc0038I Pass  54: suminf.    1.07667 (4) obj. -1068.89 iterations 15
# Cbc0038I Pass  55: suminf.    0.31429 (2) obj. -1070.48 iterations 10
# Cbc0038I Pass  56: suminf.    0.44732 (2) obj. -1068.89 iterations 12
# Cbc0038I Pass  57: suminf.    0.36701 (4) obj. -1068.89 iterations 21
# Cbc0038I Pass  58: suminf.    0.14359 (3) obj. -1068.89 iterations 9
# Cbc0038I Pass  59: suminf.    0.21093 (2) obj. -1068.89 iterations 12
# Cbc0038I Pass  60: suminf.    0.96712 (4) obj. -1068.89 iterations 17
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1969 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 14 rows 29 columns
# Cbc0038I Mini branch and bound improved solution from -1067.26 to -1070.8 (0.13 seconds)
# Cbc0038I Round again with cutoff of -1072.19
# Cbc0038I Reduced cost fixing fixed 1933 variables on major pass 4
# Cbc0038I Pass  60: suminf.    0.44444 (2) obj. -1074.87 iterations 1
# Cbc0038I Pass  61: suminf.    0.72958 (2) obj. -1072.19 iterations 10
# Cbc0038I Pass  62: suminf.    0.89566 (2) obj. -1072.19 iterations 4
# Cbc0038I Pass  63: suminf.    0.88889 (2) obj. -1072.25 iterations 7
# Cbc0038I Pass  64: suminf.    0.89566 (2) obj. -1072.19 iterations 15
# Cbc0038I Pass  65: suminf.    0.65248 (5) obj. -1072.19 iterations 10
# Cbc0038I Pass  66: suminf.    0.47905 (3) obj. -1072.19 iterations 9
# Cbc0038I Pass  67: suminf.    0.99888 (3) obj. -1072.19 iterations 10
# Cbc0038I Pass  68: suminf.    0.94345 (2) obj. -1072.19 iterations 14
# Cbc0038I Pass  69: suminf.    0.98413 (2) obj. -1072.57 iterations 11
# Cbc0038I Pass  70: suminf.    0.56007 (4) obj. -1072.19 iterations 9
# Cbc0038I Pass  71: suminf.    0.49753 (4) obj. -1072.19 iterations 14
# Cbc0038I Pass  72: suminf.    0.38936 (2) obj. -1072.19 iterations 5
# Cbc0038I Pass  73: suminf.    0.15873 (2) obj. -1073.82 iterations 13
# Cbc0038I Pass  74: suminf.    0.33257 (2) obj. -1072.19 iterations 9
# Cbc0038I Pass  75: suminf.    0.98946 (4) obj. -1072.19 iterations 10
# Cbc0038I Pass  76: suminf.    0.44911 (4) obj. -1072.19 iterations 11
# Cbc0038I Pass  77: suminf.    0.43450 (4) obj. -1072.19 iterations 8
# Cbc0038I Pass  78: suminf.    0.28912 (3) obj. -1072.19 iterations 5
# Cbc0038I Pass  79: suminf.    0.30183 (2) obj. -1072.19 iterations 11
# Cbc0038I Pass  80: suminf.    1.16564 (4) obj. -1072.19 iterations 12
# Cbc0038I Pass  81: suminf.    0.47619 (2) obj. -1072.34 iterations 5
# Cbc0038I Pass  82: suminf.    0.49184 (2) obj. -1072.19 iterations 10
# Cbc0038I Pass  83: suminf.    0.78979 (3) obj. -1072.19 iterations 7
# Cbc0038I Pass  84: suminf.    0.62106 (4) obj. -1072.19 iterations 11
# Cbc0038I Pass  85: suminf.    0.54200 (3) obj. -1072.19 iterations 7
# Cbc0038I Pass  86: suminf.    0.85727 (4) obj. -1072.19 iterations 9
# Cbc0038I Pass  87: suminf.    1.11595 (4) obj. -1072.19 iterations 9
# Cbc0038I Pass  88: suminf.    0.76487 (4) obj. -1072.19 iterations 5
# Cbc0038I Pass  89: suminf.    0.56916 (2) obj. -1072.19 iterations 8
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1980 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 7 rows 20 columns
# Cbc0038I Mini branch and bound did not improve solution (0.18 seconds)
# Cbc0038I After 0.18 seconds - Feasibility pump exiting with objective of -1070.8 - took 0.14 seconds
# Cbc0012I Integer solution of -1070.8041 found by feasibility pump after 0 iterations and 0 nodes (0.18 seconds)
# Cbc0038I Full problem 1365 rows 2001 columns, reduced to 2 rows 5 columns
# Cbc0013I At root node, 0 cuts changed objective from -1075.422 to -1075.422 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0016I Integer solution of -1071.0987 found by strong branching after 27 iterations and 0 nodes (0.19 seconds)
# Cbc0001I Search completed - best objective -1071.098723602232, took 36 iterations and 0 nodes (0.19 seconds)
# Cbc0032I Strong branching done 8 times (18 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 1886 variables fixed on reduced cost
# Cuts at root node changed objective from -1075.42 to -1070.97
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1071.09872360
# Enumerated nodes:               0
# Total iterations:               36
# Time (CPU seconds):             0.19
# Time (Wallclock seconds):       0.20
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.20   (Wallclock seconds):       0.21
#
# Total expected score = 1071.098723602295

# %%
for i in range(df.shape[0]):
    if decisions[i].value() != 0:
        print(f'{names[i]}: {expected_scores[i]} points at ${prices[i]}')
print('subs')
for i in range(df.shape[0]):
    if sub_decisions[i].value() != 0:
        print(f'{names[i]}: {expected_scores[i]} points at ${prices[i]}')
print('Capt')
#for i in range(df.shape[0]):
#    if captain_decisions[i].value != 0:
#        print(f'Captain: {names[i]} score: {captain_decisions[i].value}')
# Out:
# Ødegaard: 75.31554412841797 points at $6.4
# Toney: 83.4347915649414 points at $7.4
# Raya: 58.46512985229492 points at $4.6
# Trossard: 87.79013061523438 points at $7.1
# Tarkowski: 60.165733337402344 points at $4.4
# Castagne: 59.329505920410156 points at $4.7
# De Bruyne: 91.37598419189453 points at $12.6
# Haaland: 116.27536010742188 points at $12.2
# Trippier: 88.82398986816406 points at $5.9
# Almirón: 90.53358459472656 points at $5.8
# Kane: 99.83307647705078 points at $11.6
# subs
# Mee: 55.976802825927734 points at $4.6
# Andreas: 59.94528579711914 points at $4.6
# Ward: 53.411529541015625 points at $4.1
# N.Williams: 48.06904602050781 points at $4.0
# Capt
