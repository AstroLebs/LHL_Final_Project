# %% [markdown]
# import main
# main.main()

# %%
import pickle
import modules
year = 2022
with open(rf"../output/pickles/{year}.pickle", 'rb') as inputdata:
            db = pickle.load(inputdata)

with open(rf"../output/pickles/{year-1}.pickle", 'rb') as inputdata:
            df = pickle.load(inputdata)

# %%
keepers = [
        pd.read_csv(f"../Data/FBREF_{year-1}"+"-"+f"{year-2000}"+"/" + f)
        for f in [f"keeper_{year-2000}.csv", f"keeper_adv_{year-2000}.csv"]
    ]

# %%
# Get Players names for this dataset (FPL)
# Get Stats (Historic will be tricky)
#
# Out:
#           first_name      second_name  goals_scored  assists  total_points  \
# 0              Bernd             Leno             0        0            10
# 1         Rúnar Alex        Rúnarsson             0        0             0
# 2            Willian  Borges Da Silva             0        0             0
# 3     Pierre-Emerick       Aubameyang             4        1            44
# 4             Cédric           Soares             1        1            48
# ..               ...              ...           ...      ...           ...
# 732      Bruno André    Cavaco Jordão             0        0             0
# 733     Toti António            Gomes             0        0             6
# 734             Dion        Sanderson             0        0             0
# 735             Ryan            Giles             0        0             0
# 736  Francisco Jorge   Tomás Oliveira             0        3            20
#
# ...

# %%
player_name = "mohamed salah"
tables = pd.read_html(modules.constants.FBREF_SEARCH_URL + player_name.replace(" ", "+"))
table_num = len(tables)
scout_num = int((table_num - 9) / 2)
table_names = []
for i in range(scout_num):
    table_names.append(f"scout_{i}")
    table_names.append(f"similar_{i}")
    table_names.sort()

table_names += modules.constants.FBREF_PLAYER_LABELS
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [60], line 2
#       1 player_name = "mohamed salah"
# ----> 2 tables = pd.read_html(modules.constants.FBREF_SEARCH_URL + player_name.replace(" ", "+"))
#       3 table_num = len(tables)
#       4 scout_num = int((table_num - 9) / 2)
#
# File ~/PythonEnvs/FPL/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
tables
# Out:
# [                 Statistic Per 90  Percentile
#  0        Non-Penalty Goals   0.38        76.0
#  1           Non-Penalty xG   0.19        27.0
#  2              Shots Total   2.32        54.0
#  3                  Assists   0.06         3.0
#  4                      xAG   0.17        26.0
#  5               npxG + xAG   0.37        27.0
#  6    Shot-Creating Actions   3.66        38.0
#  7                      NaN    NaN         NaN
#  8         Passes Attempted  27.79         8.0
#  9        Pass Completion %  78.5%        61.0
#  10      Progressive Passes   2.44        34.0
#  11      Dribbles Completed   2.25        87.0
#  12       Touches (Att Pen)   4.82        71.0
#  13  Progressive Passes Rec   6.16        67.0
#  14                     NaN    NaN         NaN
#  15                 Tackles   1.56        74.0
#  16           Interceptions   0.31        24.0
#  17                  Blocks   0.94        63.0
#  18              Clearances   0.25        24.0
# ...
